# %% [markdown]
# # Test of jupyter for data analysis and visualization
#
# Some example data from csv files is loaded and analyzed.

# %%
# %matplotlib notebook
import os
import re
import qgrid
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

qgrid.nbinstall(overwrite=True)

# %% [markdown]
# ## Reading data from files to a dictionairy that is indexed by subject id

# %%
path = "./results/"
pattern = '(?:std-toj-subject-)([0-9]+)(?:.csv)'
files = sorted([f for f in os.listdir(path) if re.match(pattern,f)])
subject_ids = [int(re.match(pattern,f).groups()[0]) for f in files]
dfs = {}
for sid, f in zip(subject_ids, files):
    dfs[sid] = pd.read_csv(path+f, comment='#')

# %% [markdown]
# ## Excel like view of the raw data

# %% [markdown]
# Data of the first subject. Relevant columns are selected and shown in a table that can be sorted by clicking the column headings.
#
# I have not found a way of using tabs for multiple tables.

# %%
qgrid.show_grid(dfs[1][['t1ori','t2ori','t1lum','t2lum','correct', 'soa', 'condition']])

# %% [markdown]
# A summary may be more informative about the raw data. This time a noninteractive table is used that includes al columns of the original file. Appearently one column is replaced by "...". Perhaps the table is too big otherwise.

# %%
dfs[1].describe()
# Out:
#        Unnamed: 0         acc    accuracy  average_response_time       avg_rt  \
# count  960.000000  960.000000  960.000000             960.000000   960.000000
# mean    15.437500   66.682027   66.682027             863.547581   863.547581
# std     10.112828    1.259894    1.259894              73.532174    73.532174
# min      0.000000   63.829787   63.829787             796.693585   796.693585
# 25%      7.000000   65.978848   65.978848             813.533927   813.533927
# 50%     15.000000   66.299963   66.299963             841.672844   841.672844
# 75%     23.000000   66.748998   66.748998             871.632624   871.632624
# max     59.000000   71.250000   71.250000            1164.573741  1164.573741
#
#         bg     correct  correct_keyboard_response  count_exp  \
# count  0.0  960.000000                 960.000000      960.0
# mean   NaN    0.566667                   0.658333        0.0
# std    NaN    0.495794                   0.474516        0.0
# min    NaN    0.000000                   0.000000        0.0
# 25%    NaN    0.000000                   0.000000        0.0
# 50%    NaN    1.000000                   1.000000        0.0
# 75%    NaN    1.000000                   1.000000        0.0
# max    NaN    1.000000                   1.000000        0.0
#
#        count_keyboard_response     ...      response_time_keyboard_response  \
# count               960.000000     ...                           960.000000
# mean                525.500000     ...                           844.213377
# std                 277.272429     ...                          2226.734016
# min                  46.000000     ...                            60.164150
# 25%                 285.750000     ...                           455.025902
# 50%                 525.500000     ...                           601.589341
# 75%                 765.250000     ...                           895.859571
# max                1005.000000     ...                         65654.215599
#
#               soa       t1lum       t1ori       t2lum       t2ori  \
# count  960.000000  960.000000  960.000000  960.000000  960.000000
# mean     0.020833  117.000000   13.125000  117.000000   13.125000
# std      6.458303   45.969569   20.464497   45.969569   20.464497
# min    -10.000000   88.000000    0.000000   88.000000    0.000000
# 25%     -5.000000   88.000000    0.000000   88.000000    0.000000
# 50%      0.000000   88.000000    0.000000   88.000000    0.000000
# 75%      5.000000  128.000000   18.750000  128.000000   18.750000
# max     10.000000  224.000000   60.000000  224.000000   60.000000
#
#            time_exp  time_keyboard_response  time_sequence   condition
# count  9.600000e+02            9.600000e+02   9.600000e+02  960.000000
# mean   1.862669e+05            5.852650e+06   5.851375e+06    8.500000
# std    2.853662e-09            3.416229e+06   3.416229e+06    4.612175
# min    1.862669e+05            1.875894e+05   1.862711e+05    1.000000
# 25%    1.862669e+05            8.641002e+05   8.628081e+05    4.750000
# 50%    1.862669e+05            6.413248e+06   6.411945e+06    8.500000
# 75%    1.862669e+05            8.966132e+06   8.964819e+06   12.250000
# max    1.862669e+05            9.802383e+06   9.801112e+06   16.000000
#
# [8 rows x 21 columns]

# %%
column_names = dfs[1].columns.values.tolist()
print(column_names)
# Out:
# ['Unnamed: 0', 'acc', 'accuracy', 'average_response_time', 'avg_rt', 'bg', 'correct', 'correct_keyboard_response', 'count_exp', 'count_keyboard_response', 'count_sequence', 'response_keyboard_response', 'response_time_keyboard_response', 'soa', 't1first_resp', 't1lum', 't1ori', 't1right', 't2lum', 't2ori', 'time_exp', 'time_keyboard_response', 'time_sequence', 'condition']

# %% [markdown]
# Interesting columns can also be selected from the dataframe if not all columns are shown in these tables.

# %%
dfs[1][column_names[5:15]].describe()
# Out:
#         bg     correct  correct_keyboard_response  count_exp  \
# count  0.0  960.000000                 960.000000      960.0
# mean   NaN    0.566667                   0.658333        0.0
# std    NaN    0.495794                   0.474516        0.0
# min    NaN    0.000000                   0.000000        0.0
# 25%    NaN    0.000000                   0.000000        0.0
# 50%    NaN    1.000000                   1.000000        0.0
# 75%    NaN    1.000000                   1.000000        0.0
# max    NaN    1.000000                   1.000000        0.0
#
#        count_keyboard_response  count_sequence  \
# count               960.000000      960.000000
# mean                525.500000      479.500000
# std                 277.272429      277.272429
# min                  46.000000        0.000000
# 25%                 285.750000      239.750000
# 50%                 525.500000      479.500000
# 75%                 765.250000      719.250000
# max                1005.000000      959.000000
#
#        response_time_keyboard_response         soa
# count                       960.000000  960.000000
# mean                        844.213377    0.020833
# std                        2226.734016    6.458303
# min                          60.164150  -10.000000
# 25%                         455.025902   -5.000000
# 50%                         601.589341    0.000000
# 75%                         895.859571    5.000000
# max                       65654.215599   10.000000

# %% [markdown]
# ## Plot of the sixteen conditions for all subjects

# %% [markdown]
# Typical visualization as TOJ curves. Limited to 4 subjects as it is merely an example.

# %%
conditions = dfs[1]["condition"].drop_duplicates().values
soas = np.sort(dfs[1]["soa"].drop_duplicates().values)

# %%
for subject_id in subject_ids[1:4]:
    fig, axarr = plt.subplots(4, 4)
    for condition in conditions:
            x = [ dfs[subject_id].loc[(dfs[subject_id]["condition"] == condition) &
                                      (dfs[1]["soa"] == soa),"correct"].mean() for soa in soas]
            axarr[int((condition-1)/4), int((condition-1)%4)].plot(soas, x)
            #axarr[(condition-1)/4, (condition-1)%4].set_title("Condition: {0}".format(condition))
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# Now a modelbased analysis would follow...
